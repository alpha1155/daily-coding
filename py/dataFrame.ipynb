# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({"id":[1,2,3,4,5,6],"raw_grade":['a', 'b', 'b', 'a', 'a','e']})

# %%
df['grade'] = df['raw_grade'].astype('category')

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
df
# Out:
#    id raw_grade grade
# 0   1         a     a
# 1   2         b     b
# 2   3         b     b
# 3   4         a     a
# 4   5         a     a
# 5   6         e     e

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

# %%
ts.head()
# Out:
# 2000-01-01   -0.831360
# 2000-01-02   -0.337529
# 2000-01-03   -0.788963
# 2000-01-04    0.659068
# 2000-01-05    1.137042
# Freq: D, dtype: float64

# %%
ts= ts.cumsum()

# %%
ts
# Out:
# 2000-01-01   -0.831360
# 2000-01-02   -1.168888
# 2000-01-03   -1.957851
# 2000-01-04   -1.298783
# 2000-01-05   -0.161741
#                 ...
# 2002-09-22    4.775451
# 2002-09-23    5.529767
# 2002-09-24    5.971567
# 2002-09-25    7.390663
# 2002-09-26    9.534055
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
plt.figure()
df.plot()
plt.legend(loc="best")

# %%
import os

# 确保文件夹存在
os.makedirs("./downloads", exist_ok=True)

# 将 DataFrame 写入 CSV 文件
df.to_csv("./downloads/foo.csv")

# %%
dd = pd.read_csv("./downloads/foo.csv")

# %%
dd.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01 -0.857256 -0.879430  1.101384 -0.519994
# 1  2000-01-02 -1.208347 -1.899408  0.436549  0.960978
# 2  2000-01-03 -1.671276 -0.842651 -0.729189  1.129763
# 3  2000-01-04 -1.744714 -0.412826  0.222735  2.187314
# 4  2000-01-05 -1.116481 -1.052074 -1.524993  1.674445

# %%
df.to_hdf("./downloads/foo.h5", key="df")

# %%
pd.read_hdf('./downloads/foo.h5','df').head()
# Out:
#                    A         B         C         D
# 2000-01-01 -0.857256 -0.879430  1.101384 -0.519994
# 2000-01-02 -1.208347 -1.899408  0.436549  0.960978
# 2000-01-03 -1.671276 -0.842651 -0.729189  1.129763
# 2000-01-04 -1.744714 -0.412826  0.222735  2.187314
# 2000-01-05 -1.116481 -1.052074 -1.524993  1.674445

# %%
df.to_excel('./downloads/foo.xlsx', sheet_name='Sheet1')

# %%
pd.read_excel('./downloads/foo.xlsx', 'Sheet1', index_col=None, na_values=['NA']).head()
# Out:
#   Unnamed: 0         A         B         C         D
# 0 2000-01-01 -0.857256 -0.879430  1.101384 -0.519994
# 1 2000-01-02 -1.208347 -1.899408  0.436549  0.960978
# 2 2000-01-03 -1.671276 -0.842651 -0.729189  1.129763
# 3 2000-01-04 -1.744714 -0.412826  0.222735  2.187314
# 4 2000-01-05 -1.116481 -1.052074 -1.524993  1.674445
